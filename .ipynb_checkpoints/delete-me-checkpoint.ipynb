# %% [markdown]
# ### The goal of this notebook is to develop code allowing for sampling of Google Street View images along a path.

# %%
import streetview as sv
import geopy
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
import osmnx as ox
import networkx as nx
import math

from shapely.geometry import *

# %matplotlib inline

API_KEY = "AIzaSyDOBFEKDDeaA403gh8KVYu7pQ7jF7PMt30"

geocoder = geopy.GoogleV3()

# %%
import math
def calculate_bearing(pointA, pointB):
    """
    Calculates the bearing between two points.

    The formulae used is the following:
        θ = atan2(sin(Δlong).cos(lat2),
                  cos(lat1).sin(lat2) − sin(lat1).cos(lat2).cos(Δlong))

    :Parameters:
      - `pointA: The tuple representing the latitude/longitude for the
        first point. Latitude and longitude must be in decimal degrees
      - `pointB: The tuple representing the latitude/longitude for the
        second point. Latitude and longitude must be in decimal degrees

    :Returns:
      The bearing in degrees

    :Returns Type:
      float
      
    CREDIT: https://gist.github.com/jeromer/2005586
    """
    if (type(pointA) != tuple) or (type(pointB) != tuple):
        raise TypeError("Only tuples are supported as arguments")

    lat1 = math.radians(pointA[0])
    lat2 = math.radians(pointB[0])

    diffLong = math.radians(pointB[1] - pointA[1])

    x = math.sin(diffLong) * math.cos(lat2)
    y = math.cos(lat1) * math.sin(lat2) - (math.sin(lat1)
            * math.cos(lat2) * math.cos(diffLong))

    initial_bearing = math.atan2(x, y)

    # Now we have the initial bearing but math.atan2 return values
    # from -180° to + 180° which is not what we want for a compass bearing
    # The solution is to normalize the initial bearing as shown below
    initial_bearing = math.degrees(initial_bearing)
    compass_bearing = (initial_bearing + 360) % 360

    return compass_bearing

# %%
calculate_bearing((0, 0), (-10, 0))
# Out:
# 180.0

# %%
def show_img(img):
    img = Image.open(img)
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.imshow(np.asarray(img))

# %%
def get_image(lat1, lon1, bearing=0.0):
    panoid_infos = sv.panoids(lat1, lon1)
    panoids = [p['panoid'] for p in panoid_infos]
    pancoords = [(p['lat'], p['lon']) for p in panoid_infos]
    
    if not panoids or not pancoords:
        return None
    
    pid = panoids[0]
    lat, lon = pancoords[0]
    
    print 'COORDS:', (lat, lon)
    #bearing = int(calc_bearing(lat, lon, lat1, lon1))
    
    return sv.api_download(panoids[0], bearing, '.', key=API_KEY)

# %%
lat1, lon1 = geocoder.geocode('617 St. Johns Street Brooklyn, NY')._tuple[1]
img = get_image(lat1, lon1)
show_img(img)
# Out:
# COORDS: (40.67252750243006, -73.95787388428839)

# %%
from functools import partial

def cut(line, distance):
    # Cuts a line in two at a distance from its starting point
    if distance <= 0.0 or distance >= line.length:
        return [LineString(line)]
    
    coords = list(line.coords)
    
    for i, p in enumerate(coords):
        pd = line.project(Point(p))
        if pd == distance:
            return [
                LineString(coords[:i+1]),
                LineString(coords[i:])]
        if pd > distance:
            cp = line.interpolate(distance)
            return [
                LineString(coords[:i] + [(cp.x, cp.y)]),
                LineString([(cp.x, cp.y)] + coords[i:])]

def reproject(geom, from_crs, to_crs):
    # https://gis.stackexchange.com/questions/127427/transforming-shapely-polygon-and-multipolygon-objects
    from functools import partial
    import pyproj
    from shapely.ops import transform

    project = partial(
        pyproj.transform,
        pyproj.Proj(init='epsg:{}'.format(from_crs)), # source coordinate system
        pyproj.Proj(init='epsg:{}'.format(to_crs))) # destination coordinate system
    
    return transform(project, geom)  # apply projection

def sample_pts(road, delta=30.0, from_crs=4326, to_crs=32611):
    segment = reproject(road, from_crs, to_crs)
    samples = []
    
    while segment.length > delta:
        segment = cut(segment, delta)[-1]    
        p1, p2 = segment.coords[:2]
        
        bearing = calculate_bearing(p1[::-1], p2[::-1])
        samples.append((reproject(Point(p1), to_crs, from_crs).coords[0], (bearing + 90.0) % 360, (bearing + 270.0) % 360))

    p1, p2 = segment.coords[-2:]    
    bearing = calculate_bearing(p1[::-1], p2[::-1])
    samples.append((reproject(Point(p2), to_crs, from_crs).coords[0], (bearing + 90.0) % 360, (bearing + 270.0) % 360))

    return samples

# %% [markdown]
# ### Try on actual road

# %%
G = ox.graph_from_place("Oak Park, Il")

# %%
geoms = [atts.get('geometry') for u, v, atts in G.edges(data=True) if atts.get('geometry')]
g = geoms[-15]

# %%
g.wkt
# Out:
# 'LINESTRING (-87.80410379999999 41.8886057, -87.8045066 41.8885978, -87.8049262 41.8885895)'

# %%
g.length
# Out:
# 0.0008225595448214975

# %%
samples = sample_pts(g, delta=10, to_crs=26915)

# %% [raw]
# REMEMBER: The end of the street will also likely be an intersection!  So may be looking at cross street!

# %%
for (lat, lon), b1, b2 in samples:
    i1 = get_image(lon, lat, b1)
    i2 = get_image(lon, lat, b2)
    
    print lat, lon, b1, b2
    show_img(i1)
    show_img(i2)

# %%
def get_epsg_code(lon, lat):
    # inspired by osmnx
    utm_zone = int(math.floor((lon + 180) / 6.) + 1)
    ns = 6 if lat > 0 else 7
    
    return "32{}{}".format(ns, utm_zone)

# %%
get_epsg_code(117.0, 32.0)
# Out:
# '32650'
